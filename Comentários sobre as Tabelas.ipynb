# %%
# %sql
ALTER TABLE portfolio_energia.bronze.ccee_pld_horario
ALTER COLUMN MES_REFERENCIA COMMENT 'Representa o período de referência dos dados, composto pelo mês e o ano correspondentes.';

ALTER TABLE portfolio_energia.bronze.ccee_pld_horario
ALTER COLUMN SUBMERCADO COMMENT 'Representa os quatro (4) submercados de atuação no Sistema Interligado Nacional (SIN) correspondentes ao Sudeste (SE), Sul (S), Nordeste (NE) e Norte (N).';

ALTER TABLE portfolio_energia.bronze.ccee_pld_horario
ALTER COLUMN PERIODO_COMERCIALIZACAO COMMENT 'Representa o período de comercialização, equivalente a uma hora, dentro do mês e o ano de referência aos quais os dados estão associados.';

ALTER TABLE portfolio_energia.bronze.ccee_pld_horario
ALTER COLUMN DIA COMMENT 'Representa o dia vinculado ao mês e ano de referência aos quais os dados estão associados.';

ALTER TABLE portfolio_energia.bronze.ccee_pld_horario
ALTER COLUMN HORA COMMENT 'Representa a hora do dia aos quais os dados estão associados.';

ALTER TABLE portfolio_energia.bronze.ccee_pld_horario
ALTER COLUMN PLD_HORA COMMENT 'Corresponde ao Preço de Liquidação das Diferenças, determinado por submercado "s", por período de comercialização "j" (PLDs,j) R$/MWh';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN id_subsistema COMMENT 'Código do Subsistema da Usina';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN nom_subsistema COMMENT 'Nome do Subsistema ';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN din_instante COMMENT 'Data de Referência';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN val_gerhidraulica COMMENT 'Valor verificado de geração
hidráulica, em MWmed';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN val_gertermica COMMENT 'Valor verificado de geração
térmica, em MWmed';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN val_gereolica COMMENT 'Valor verificado de geração eólica,
em MWmed';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN val_gersolar COMMENT 'Valor verificado de geração
fotovoltaica, em MWmed';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN val_carga COMMENT 'Valor verificado da carga, em
MWmed';

ALTER TABLE portfolio_energia.bronze.ons_balanco_energia_subsistema
ALTER COLUMN val_intercambio COMMENT 'Valor verificado do intercâmbio
líquido, em MWmed';
